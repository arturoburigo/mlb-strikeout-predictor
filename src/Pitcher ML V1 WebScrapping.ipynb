# %%
import pandas as pd
import numpy as np
import os
import time
import random
import html5lib

# %%
# Ler o arquivo betting_data.csv
betting_data_df = pd.read_csv('betting_data.csv')

seasons = [str(season) for season in range(2023, 2025)]
print(f'number of seasons={len(seasons)}')

# Criar a lista de pitchers a partir da coluna Name_abbreviation
pitchers = betting_data_df['Name_abbreviation'].tolist()
print(f'number of pitchers={len(pitchers)}')


print(f'number of pitchers={len(pitchers)}')


# Criar uma lista vazia para armazenar os DataFrames
dataframes = []
# Out:
# number of seasons=2
# number of pitchers=25
# number of pitchers=25

# %%
# Verifica se o arquivo CSV já existe
if os.path.exists('pitchers_data.csv'):
    existing_df = pd.read_csv('pitchers_data.csv')  # Lê o DataFrame existente
else:
    existing_df = pd.DataFrame(columns=['Season', 'Pitcher'])  # Cria um DataFrame vazio com as colunas necessárias

# Função para tentar carregar dados de um pitcher com diferentes IDs
def load_pitcher_data(pitcher, season):
    for id_suffix in ['01', '02', '03', '04']:
        url = f"https://www.baseball-reference.com/players/gl.fcgi?id={pitcher}{id_suffix}&t=p&year={season}"
        print(url)
        try:
            # Correção da chamada do pd.read_html
            pitcher_gl = pd.read_html(url, header=0, attrs={'id': 'pitching_gamelogs'})[0]

            # Adicionando a coluna 'Season'
            pitcher_gl.insert(loc=0, column='Season', value=season)

            # Adicionando a coluna 'Pitcher'
            pitcher_gl.insert(loc=2, column='Pitcher', value=pitcher.lower())

            return pitcher_gl  # Retorna o DataFrame se encontrado
        except (ValueError, IndexError):
            print(f"Dados não encontrados para o pitcher {pitcher.lower()} com ID {id_suffix} na temporada {season}. Tentando próximo...")
            time.sleep(random.randint(7, 8))

    return None  # Retorna None se nenhum ID funcionou

for season in seasons:
    for pitcher in pitchers:
        pitcher_data = load_pitcher_data(pitcher, season)
        
        if pitcher_data is not None:
            # Verifica se o pitcher já está no DataFrame existente
            if pitcher_data['Pitcher'].iloc[0] not in existing_df['Pitcher'].values:
                # Armazenando o DataFrame em uma lista
                dataframes.append(pitcher_data)
            else:
                print(f"O pitcher {pitcher.lower()} já existe no arquivo CSV. Ignorando...")
        else:
            print(f"Nenhum dado encontrado para o pitcher {pitcher.lower()} na temporada {season}.")

        # Espera aleatória para não sobrecarregar o servidor
        time.sleep(random.randint(7, 8))

# Concatenando todos os DataFrames da lista em um único DataFrame, se houver dados
if dataframes:
    new_pitchers_df = pd.concat(dataframes, ignore_index=True)

    # Realizando a limpeza de dados
    if 'Rk' in new_pitchers_df.columns:
        new_pitchers_df = new_pitchers_df[new_pitchers_df['Rk'].apply(lambda x: str(x).isdigit())]
        new_pitchers_df.reset_index(drop=True, inplace=True)
        print("Linhas não inteiras foram removidas com sucesso.")
    else:
        print("A coluna 'Rk' não existe no DataFrame.")

    # Colunas a serem removidas do dataframe
    new_pitchers_df.drop(columns=['Rk', 'Gcar', 'Tm', 'Gtm', 'Date', 'Rslt', 'Inngs', 'Dec', 'ER', 'SB', 'CS', 'PO', 'DFS(DK)', 'DFS(FD)'], inplace=True, errors='ignore')

    # Renomeando a coluna 'Unnamed: 5' para 'Home'
    new_pitchers_df.rename(columns={'Unnamed: 5': 'Home'}, inplace=True)

    # Preenchendo valores NaN com 0
    new_pitchers_df['Home'] = new_pitchers_df['Home'].fillna(0)

    # Aplicando a função lambda para mudar '@' para 1 e manter os outros valores
    new_pitchers_df['Home'] = new_pitchers_df['Home'].apply(lambda x: 1 if x == '@' else 0)

    # Convertendo a coluna 'Home' para tipo int (se ainda não estiver)
    new_pitchers_df['Home'] = new_pitchers_df['Home'].astype(int)

    # Exibindo as informações do DataFrame
    print(new_pitchers_df.info(verbose=True))

    # Colunas a manter, incluindo a coluna Season
    columns_to_keep = [
        'Season',   # Temporada
        'Pitcher',  # Nome do pitcher
        'Home',     # Se o jogo é em casa (1) ou fora (0)
        'Opp',      # Oponente
        'IP',       # Innings pitched
        'H',        # Hits permitidos
        'BB',       # Walks permitidos
        'SO',       # Strikeouts (número de strikeouts do pitcher)
        'ERA',      # Earned Run Average
        'FIP',      # Fielding Independent Pitching
        'GB',       # Ground Balls
        'FB',       # Fly Balls
        'LD',       # Line Drives
        'PU',       # Pop Ups
        'WPA'       # Win Probability Added
    ]

    # Dropar as colunas que não estão na lista
    new_pitchers_df = new_pitchers_df[columns_to_keep]

    # Exibir informações do DataFrame após o drop
    print(new_pitchers_df.info(verbose=True))

    # Concatenar com os dados existentes
    combined_df = pd.concat([existing_df, new_pitchers_df], ignore_index=True)

    # Salvando o DataFrame em um arquivo CSV
    combined_df.to_csv('pitchers_data.csv', index=False)

    print("Arquivo CSV salvo com sucesso!")
else:
    print("Nenhum dado novo foi coletado para salvar.")
# Out:
# https://www.baseball-reference.com/players/gl.fcgi?id=eflinza01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=steelju01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=bibeeta01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=kingmi01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=lopezpa01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=skubata01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=raganco01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=galleza01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=alcansa01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=gilbelo01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=peralfr01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=grayso01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=rodonca01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=severlu01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=skenepa01&t=p&year=2023
# Dados não encontrados para o pitcher skenepa com ID 01 na temporada 2023. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=skenepa02&t=p&year=2023
# Dados não encontrados para o pitcher skenepa com ID 02 na temporada 2023. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=skenepa03&t=p&year=2023
# Dados não encontrados para o pitcher skenepa com ID 03 na temporada 2023. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=skenepa04&t=p&year=2023
# Dados não encontrados para o pitcher skenepa com ID 04 na temporada 2023. Tentando próximo...
# Nenhum dado encontrado para o pitcher skenepa na temporada 2023.
# https://www.baseball-reference.com/players/gl.fcgi?id=crochga01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=berrijo01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=snellbl01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=kikucyu01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=gorema01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=webblo01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=holmecl01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=valdefr01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=greenhu01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=eovalna01&t=p&year=2023
# https://www.baseball-reference.com/players/gl.fcgi?id=eflinza01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=steelju01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=bibeeta01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=kingmi01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=lopezpa01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=skubata01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=raganco01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=galleza01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=alcansa01&t=p&year=2024
# Dados não encontrados para o pitcher alcansa com ID 01 na temporada 2024. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=alcansa02&t=p&year=2024
# Dados não encontrados para o pitcher alcansa com ID 02 na temporada 2024. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=alcansa03&t=p&year=2024
# Dados não encontrados para o pitcher alcansa com ID 03 na temporada 2024. Tentando próximo...
# https://www.baseball-reference.com/players/gl.fcgi?id=alcansa04&t=p&year=2024
# Dados não encontrados para o pitcher alcansa com ID 04 na temporada 2024. Tentando próximo...
# Nenhum dado encontrado para o pitcher alcansa na temporada 2024.
# https://www.baseball-reference.com/players/gl.fcgi?id=gilbelo01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=peralfr01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=grayso01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=rodonca01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=severlu01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=skenepa01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=crochga01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=berrijo01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=snellbl01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=kikucyu01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=gorema01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=webblo01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=holmecl01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=valdefr01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=greenhu01&t=p&year=2024
# https://www.baseball-reference.com/players/gl.fcgi?id=eovalna01&t=p&year=2024
# Linhas não inteiras foram removidas com sucesso.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1483 entries, 0 to 1482
# Data columns (total 41 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   1483 non-null   object
#  1   Pitcher  1483 non-null   object
#  2   Home     1483 non-null   int64
#  3   Opp      1483 non-null   object
#  4   DR       1483 non-null   object
#  5   IP       1483 non-null   object
#  6   H        1483 non-null   object
#  7   R        1483 non-null   object
#  8   BB       1483 non-null   object
#  9   SO       1483 non-null   object
#  10  HR       1483 non-null   object
#  11  HBP      1483 non-null   object
#  12  ERA      1483 non-null   object
#  13  FIP      1483 non-null   object
#  14  BF       1483 non-null   object
#  15  Pit      1482 non-null   object
#  16  Str      1482 non-null   object
#  17  StL      1482 non-null   object
#  18  StS      1482 non-null   object
#  19  GB       1482 non-null   object
#  20  FB       1482 non-null   object
#  21  LD       1482 non-null   object
#  22  PU       1482 non-null   object
#  23  Unk      1482 non-null   object
#  24  GSc      1278 non-null   object
#  25  IR       205 non-null    object
#  26  IS       205 non-null    object
#  27  AB       1483 non-null   object
#  28  2B       1483 non-null   object
#  29  3B       1483 non-null   object
#  30  IBB      1483 non-null   object
#  31  GDP      1483 non-null   object
#  32  SF       1483 non-null   object
#  33  ROE      1483 non-null   object
#  34  aLI      1482 non-null   object
#  35  WPA      1482 non-null   object
#  36  acLI     1482 non-null   object
#  37  cWPA     1482 non-null   object
#  38  RE24     1482 non-null   object
#  39  Entered  1482 non-null   object
#  40  Exited   1482 non-null   object
# dtypes: int64(1), object(40)
# memory usage: 475.2+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1483 entries, 0 to 1482
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   1483 non-null   object
#  1   Pitcher  1483 non-null   object
#  2   Home     1483 non-null   int64
#  3   Opp      1483 non-null   object
#  4   IP       1483 non-null   object
#  5   H        1483 non-null   object
#  6   BB       1483 non-null   object
#  7   SO       1483 non-null   object
#  8   ERA      1483 non-null   object
#  9   FIP      1483 non-null   object
#  10  GB       1482 non-null   object
#  11  FB       1482 non-null   object
#  12  LD       1482 non-null   object
#  13  PU       1482 non-null   object
#  14  WPA      1482 non-null   object
# dtypes: int64(1), object(14)
# memory usage: 173.9+ KB
# None
# Arquivo CSV salvo com sucesso!
