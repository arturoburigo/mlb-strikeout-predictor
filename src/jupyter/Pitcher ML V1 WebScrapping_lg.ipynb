# %%
import pandas as pd
import os
import time
import random
import glob
from datetime import datetime

# Ler o arquivo betting_data mais recente
betting_files = glob.glob('betting_data_*.csv')
    
if not betting_files:
    # Fallback to the default name if no date-specific files found
    betting_file = 'betting_data.csv'
    print(f"Usando arquivo padrão: {betting_file}")
else:
    # Sort files by date (assuming format betting_data_YYYY-MM-DD.csv)
    betting_files.sort(key=lambda x: datetime.strptime(x.split('_')[2].split('.')[0], '%Y-%m-%d'), reverse=True)
    betting_file = betting_files[0]
    print(f"Usando arquivo mais recente: {betting_file}")

betting_data_df = pd.read_csv(betting_file)

# Foco apenas em 2024
season = 2024
print(f'Buscando dados para a temporada {season}')

# Criar a lista de pitchers a partir da coluna Name_abbreviation
pitchers = betting_data_df['Name_abbreviation'].tolist()
print(f'Número de pitchers: {len(pitchers)}')

# Lista para armazenar os dados do último jogo de cada pitcher
last_games = []

# Função para carregar o último jogo de um pitcher
def load_last_pitcher_game(pitcher, season):
    for id_suffix in ['01', '02', '03', '04']:
        url = f"https://www.baseball-reference.com/players/gl.fcgi?id={pitcher}{id_suffix}&t=p&year={season}"
        print(f"Tentando URL: {url}")
        try:
            # Carregar tabela de jogos do pitcher
            pitcher_gl = pd.read_html(url, header=0, attrs={'id': 'pitching_gamelogs'})[0]
            
            # Verificar se há dados válidos
            if pitcher_gl.empty:
                print(f"Tabela vazia para {pitcher} com ID {id_suffix}")
                continue
                
            # Filtrar apenas linhas com Rk numérico (dados válidos de jogos)
            pitcher_gl = pitcher_gl[pitcher_gl['Rk'].apply(lambda x: str(x).isdigit())]
            
            if pitcher_gl.empty:
                print(f"Nenhum jogo válido para {pitcher} com ID {id_suffix}")
                continue
                
            # Pegar o último jogo (maior valor de Rk)
            last_game = pitcher_gl.loc[pitcher_gl['Rk'].astype(int).idxmax()]
            
            # Adicionar informações do pitcher e temporada
            last_game['Season'] = season
            last_game['Pitcher'] = pitcher.lower()
            
            print(f"Último jogo encontrado para {pitcher} na temporada {season}")
            return last_game.to_dict()
            
        except (ValueError, IndexError) as e:
            print(f"Erro ao buscar dados para {pitcher} com ID {id_suffix}: {e}")
            time.sleep(random.randint(3, 5))  # Reduzir o tempo de espera
    
    print(f"Nenhum dado encontrado para {pitcher} na temporada {season}")
    return None

# Buscar o último jogo de cada pitcher
for pitcher in pitchers:
    last_game = load_last_pitcher_game(pitcher, season)
    if last_game:
        last_games.append(last_game)
    # Espera aleatória para não sobrecarregar o servidor
    time.sleep(random.randint(3, 5))  # Reduzir o tempo de espera

# Criar DataFrame com os últimos jogos
if last_games:
    last_games_df = pd.DataFrame(last_games)
    
    # Selecionar colunas relevantes, se presentes no DataFrame
    columns_to_keep = [
        'Season',   # Temporada
        'Pitcher',  # Nome do pitcher
        'Date',     # Data do jogo
        'Opp',      # Oponente
        'Home',     # Se o jogo é em casa (1) ou fora (0)
        'IP',       # Innings pitched
        'H',        # Hits permitidos
        'BB',       # Walks permitidos
        'SO',       # Strikeouts
        'ERA',      # Earned Run Average
        'FIP',      # Fielding Independent Pitching
        'GB',       # Ground Balls
        'FB',       # Fly Balls
        'LD',       # Line Drives
        'PU',       # Pop Ups
        'WPA'       # Win Probability Added
    ]
    
    # Manter apenas as colunas que existem no DataFrame
    available_columns = [col for col in columns_to_keep if col in last_games_df.columns]
    last_games_df = last_games_df[available_columns]
    
    # Processar a coluna Home se existir e tiver valor 'Unnamed: 5'
    if 'Unnamed: 5' in last_games_df.columns:
        last_games_df.rename(columns={'Unnamed: 5': 'Home'}, inplace=True)
        last_games_df['Home'] = last_games_df['Home'].fillna(0)
        last_games_df['Home'] = last_games_df['Home'].apply(lambda x: 1 if x == '@' else 0)
        last_games_df['Home'] = last_games_df['Home'].astype(int)
    
    # Imprimir o resultado
    print("\nÚltimos jogos de cada pitcher em 2024:")
    print(last_games_df)
    
    # Também imprimir informações estatísticas
    print("\nEstatísticas gerais:")
    print(last_games_df.describe())
else:
    print("Nenhum dado de último jogo foi encontrado para qualquer pitcher.")
# Out:
# Usando arquivo mais recente: betting_data_2025-03-30.csv
# Buscando dados para a temporada 2024
# Número de pitchers: 24
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=degroja01&t=p&year=2024
# Nenhum jogo válido para degroja com ID 01
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=degroja02&t=p&year=2024
# Erro ao buscar dados para degroja com ID 02: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=degroja03&t=p&year=2024
# Erro ao buscar dados para degroja com ID 03: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=degroja04&t=p&year=2024
# Erro ao buscar dados para degroja com ID 04: No tables found
# Nenhum dado encontrado para degroja na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=oberba01&t=p&year=2024
# Último jogo encontrado para oberba na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=bibeeta01&t=p&year=2024
# Último jogo encontrado para bibeeta na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=meyerma01&t=p&year=2024
# Último jogo encontrado para meyerma na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=nolaaa01&t=p&year=2024
# Último jogo encontrado para nolaaa na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=bradlta01&t=p&year=2024
# Último jogo encontrado para bradlta na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=heanean01&t=p&year=2024
# Último jogo encontrado para heanean na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=suganto01&t=p&year=2024
# Erro ao buscar dados para suganto com ID 01: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=suganto02&t=p&year=2024
# Erro ao buscar dados para suganto com ID 02: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=suganto03&t=p&year=2024
# Erro ao buscar dados para suganto com ID 03: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=suganto04&t=p&year=2024
# Erro ao buscar dados para suganto com ID 04: No tables found
# Nenhum dado encontrado para suganto na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=kochaja01&t=p&year=2024
# Último jogo encontrado para kochaja na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=pivetni01&t=p&year=2024
# Último jogo encontrado para pivetni na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=boydma01&t=p&year=2024
# Último jogo encontrado para boydma na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=searsjp01&t=p&year=2024
# Último jogo encontrado para searsjp na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=woobr01&t=p&year=2024
# Último jogo encontrado para woobr na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=pallaan01&t=p&year=2024
# Último jogo encontrado para pallaan na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=martida01&t=p&year=2024
# Erro ao buscar dados para martida com ID 01: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=martida02&t=p&year=2024
# Erro ao buscar dados para martida com ID 02: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=martida03&t=p&year=2024
# Último jogo encontrado para martida na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=rodried01&t=p&year=2024
# Erro ao buscar dados para rodried com ID 01: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=rodried02&t=p&year=2024
# Erro ao buscar dados para rodried com ID 02: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=rodried03&t=p&year=2024
# Erro ao buscar dados para rodried com ID 03: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=rodried04&t=p&year=2024
# Erro ao buscar dados para rodried com ID 04: No tables found
# Nenhum dado encontrado para rodried na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=stromma01&t=p&year=2024
# Último jogo encontrado para stromma na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=wachami01&t=p&year=2024
# Último jogo encontrado para wachami na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=civalaa01&t=p&year=2024
# Último jogo encontrado para civalaa na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=bassich01&t=p&year=2024
# Último jogo encontrado para bassich na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=martini01&t=p&year=2024
# Último jogo encontrado para martini na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=fittsri01&t=p&year=2024
# Nenhum jogo válido para fittsri com ID 01
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=fittsri02&t=p&year=2024
# Erro ao buscar dados para fittsri com ID 02: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=fittsri03&t=p&year=2024
# Erro ao buscar dados para fittsri com ID 03: No tables found
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=fittsri04&t=p&year=2024
# Erro ao buscar dados para fittsri com ID 04: No tables found
# Nenhum dado encontrado para fittsri na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=parkemi01&t=p&year=2024
# Último jogo encontrado para parkemi na temporada 2024
# Tentando URL: https://www.baseball-reference.com/players/gl.fcgi?id=feltnry01&t=p&year=2024
# Último jogo encontrado para feltnry na temporada 2024
#
# Últimos jogos de cada pitcher em 2024:
#     Season  Pitcher    Date  Opp   IP   H BB SO   ERA   FIP  GB  FB LD PU  \
# 0     2024   oberba  Sep 29  BAL  5.0   5  0  4  3.98  3.82   5  11  4  1
# 1     2024  bibeeta  Sep 24  CIN  7.0   4  2  7  3.47  3.56   9   7  3  2
# 2     2024  meyerma   Sep 3  WSN  5.2   9  1  5  5.68  5.90   9  11  6  0
# 3     2024   nolaaa  Sep 29  WSN  5.0   9  0  7  3.57  3.94  10   6  4  0
# 4     2024  bradlta  Sep 27  BOS  6.0   3  1  7  4.11  4.09   8   5  2  1
# 5     2024  heanean  Sep 28  LAA  4.0  10  0  3  4.28  4.04   8  11  5  2
# 6     2024  kochaja  Sep 29  TEX  7.0   6  1  1  3.99  4.62  15  11  6  4
# 7     2024  pivetni  Sep 27  TBR  6.2   4  1  6  4.14  4.07   8   9  2  3
# 8     2024   boydma  Sep 21  STL  4.0   4  3  6  2.72  3.29   3   7  3  2
# 9     2024  searsjp  Sep 27  SEA  6.0   4  3  4  4.38  4.71   3  15  2  5
# 10    2024    woobr  Sep 27  OAK  5.0   3  1  8  2.89  3.40   6   4  2  1
# 11    2024  pallaan  Sep 28  SFG  5.0   7  0  4  3.78  3.71  10   7  5  0
# 12    2024  martida  Sep 25  LAA  3.2   3  5  4  4.32  4.27   3   5  0  2
# 13    2024  stromma  Sep 25  BAL  3.1  10  0  1  4.31  4.62  11   7  4  0
# 14    2024  wachami  Sep 26  WSN  5.0   5  1  2  3.35  3.65   9  10  3  2
# 15    2024  civalaa  Sep 26  PIT  6.0   3  1  5  4.36  4.74  10   7  3  2
# 16    2024  bassich  Sep 23  BOS  4.1   4  7  2  4.16  4.08   4  10  8  0
# 17    2024  martini  Sep 27  CHC  8.0   5  0  3  3.10  3.21  11  13  7  1
# 18    2024  parkemi  Sep 24  KCR  5.0   5  2  5  4.29  3.85  11   4  2  0
# 19    2024  feltnry  Sep 29  LAD  6.0   2  2  3  4.49  4.16   8   8  1  2
#
#        WPA
# 0   -0.129
# 1    0.254
# 2   -0.208
# 3   -0.026
# 4    0.360
# 5   -0.406
# 6    0.002
# 7    0.187
# 8   -0.039
# 9   -0.017
# 10   0.258
# 11  -0.212
# 12   0.114
# 13  -0.319
# 14  -0.160
# 15   0.305
# 16  -0.174
# 17   0.231
# 18   0.277
# 19   0.209
#
# Estatísticas gerais:
#        Season
# count    20.0
# mean   2024.0
# std       0.0
# min    2024.0
# 25%    2024.0
# 50%    2024.0
# 75%    2024.0
# max    2024.0
