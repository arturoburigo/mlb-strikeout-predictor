# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
df = pd.read_csv('../pitchers_data.csv')


# Exibindo informações básicas
print("=== INFORMAÇÕES BÁSICAS ===")
print(f"Dimensões do dataset: {df.shape}")
print(f"\nPrimeiras 5 linhas:")
print(df.head())

print(f"\nInformações do dataset:")
print(df.info())

print(f"\nEstatísticas descritivas:")
print(df.describe())

# =============================================================================
# CÉLULA 3: VERIFICAÇÃO DE QUALIDADE DOS DADOS
# =============================================================================

# Verificando se há valores nulos
print("=== VERIFICAÇÃO DE DADOS NULOS ===")
print(df.isnull().sum())

# Verificando valores únicos por coluna
print(f"\n=== VALORES ÚNICOS ===")
for col in df.columns:
    print(f"{col}: {df[col].nunique()} valores únicos")

# Verificando se há valores duplicados
print(f"\nLinhas duplicadas: {df.duplicated().sum()}")


df = df[df['IP'] >= 1]

print(f"\nApós remover linhas com IP < 1, o dataset possui {df.shape[0]} linhas e {df.shape[1]} colunas.")
# Out:
# === INFORMAÇÕES BÁSICAS ===
# Dimensões do dataset: (644, 19)
#
# Primeiras 5 linhas:
#    Season  Pitcher  Home  Opp   IP  H  BB  SO  WPA   ERA   FIP  BF  Pit  Str  \
# 0    2023  peterda   1.0  MIA  5.0  8   1   5  0.2  1.80  4.46  22   84   51
# 1    2023  peterda   1.0  MIL  4.0  5   5   5 -0.2  6.00  5.92  21   92   49
# 2    2023  peterda   0.0  SDP  5.2  6   2   6  0.0  4.91  4.48  24   89   63
# 3    2023  peterda   1.0  LAD  6.0  7   0   6 -0.4  6.10  5.43  25   94   61
# 4    2023  peterda   1.0  SFG  5.0  7   1   8 -0.4  7.36  5.51  25   98   64
#
#    StS  StL  DR   aLI  opp_so_avg
# 0   10   13  99  1.04       65.90
# 1   11   12   4  1.04       65.98
# 2   10   14   5  1.17       63.55
# 3   13   19   5  0.94       60.00
# 4   13   17   4  0.64       68.88
#
# Estatísticas descritivas:
#             Season        Home          IP           H          BB  \
# count   644.000000  644.000000  644.000000  644.000000  644.000000
# mean   2023.482919    0.484472    4.931832    4.877329    1.636646
# std       0.500097    0.500147    1.695597    2.331510    1.262558
# min    2023.000000    0.000000    0.100000    0.000000    0.000000
# 25%    2023.000000    0.000000    4.100000    3.000000    1.000000
# 50%    2023.000000    0.000000    5.100000    5.000000    1.000000
# 75%    2024.000000    1.000000    6.000000    7.000000    2.000000
# max    2024.000000    1.000000    9.000000   12.000000    7.000000
#
#                SO         WPA         ERA         FIP          BF         Pit  \
# count  644.000000  644.000000  644.000000  644.000000  644.000000  644.000000
# mean     4.608696    0.008540    4.238183    4.401755   21.422360   82.734472
# std      2.432731    0.223513    2.542676    1.299613    5.933158   22.666615
# min      0.000000   -0.600000    0.000000    1.970000    2.000000    6.000000
# 25%      3.000000   -0.200000    3.097500    3.680000   20.000000   79.000000
# 50%      4.500000    0.000000    3.935000    4.260000   23.000000   89.000000
# 75%      6.000000    0.200000    4.952500    4.830000   25.000000   96.000000
# max     12.000000    0.600000   38.570000   18.860000   32.000000  123.000000
#
#               Str         StS         StL          DR         aLI  opp_so_avg
# count  644.000000  644.000000  644.000000  644.000000  644.000000  644.000000
# mean    53.063665    8.301242   14.350932    9.532609    0.974876   65.415590
